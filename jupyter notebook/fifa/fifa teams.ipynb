# %%
import pandas as pd

# %%
file_path = 'male_teams.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    team_id                           team_url  fifa_version  fifa_update  \
# 0       10    /team/10/manchester-city/240002            24            2
# 1      243       /team/243/real-madrid/240002            24            2
# 2     1318          /team/1318/england/240002            24            2
# 3       21  /team/21/fc-bayern-munchen/240002            24            2
# 4      241      /team/241/fc-barcelona/240002            24            2
#
#   update_as_of          team_name  league_id             league_name  \
# 0   2023-09-22    Manchester City         13          Premier League
# 1   2023-09-22        Real Madrid         53                 La Liga
# 2   2023-09-22            England         78  Friendly International
# 3   2023-09-22  FC Bayern München         19              Bundesliga
# 4   2023-09-22       FC Barcelona         53                 La Liga
#
#    league_level  nationality_id  ... off_corners  off_free_kicks  \
# ...

# %%
df.tail()
# Out:
#       team_id                           team_url  fifa_version  fifa_update  \
# 6942      305       /team/305/bohemian-fc/150002            15            2
# 6943     1572  /team/1572/drogheda-united/150002            15            2
# 6944      838    /team/838/bray-wanderers/150002            15            2
# 6945   111132        /team/111132/ucd-afc/150002            15            2
# 6946   111965   /team/111965/athlone-town/150002            15            2
#
#      update_as_of        team_name  league_id       league_name  league_level  \
# 6942   2014-09-18        Bohemians         65  Premier Division           1.0
# 6943   2014-09-18  Drogheda United         65  Premier Division           1.0
# 6944   2014-09-18   Bray Wanderers         65  Premier Division           1.0
# 6945   2014-09-18              UCD         65  Premier Division           1.0
# 6946   2014-09-18     Athlone Town         65  Premier Division           1.0
#
# ...

# %%
df.describe()
# Out:
#              team_id  fifa_version  fifa_update    league_id  league_level  \
# count    6947.000000   6947.000000       6947.0  6947.000000   6497.000000
# mean    44950.297682     19.608320          2.0   216.713977      1.386640
# std     53463.946306      2.836743          0.0   460.967263      0.761282
# min         1.000000     15.000000          2.0     1.000000      1.000000
# 25%       485.000000     17.000000          2.0    20.000000      1.000000
# 50%      1880.000000     20.000000          2.0    60.000000      1.000000
# 75%    110932.500000     22.000000          2.0   308.000000      2.000000
# max    131389.000000     24.000000          2.0  2149.000000      5.000000
#
#        nationality_id      overall       attack     midfield      defence  \
# count     6947.000000  6947.000000  6947.000000  6947.000000  6947.000000
# mean        49.504966    68.941845    69.409097    68.796603    68.254930
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6947 entries, 0 to 6946
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   team_id                      6947 non-null   int64
#  1   team_url                     6947 non-null   object
#  2   fifa_version                 6947 non-null   int64
#  3   fifa_update                  6947 non-null   int64
#  4   update_as_of                 6947 non-null   object
#  5   team_name                    6947 non-null   object
#  6   league_id                    6947 non-null   int64
#  7   league_name                  6947 non-null   object
#  8   league_level                 6497 non-null   float64
#  9   nationality_id               6947 non-null   int64
#  10  nationality_name             6947 non-null   object
#  11  overall                      6947 non-null   int64
#  12  attack                       6947 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# team_id                           0
# team_url                          0
# fifa_version                      0
# fifa_update                       0
# update_as_of                      0
# team_name                         0
# league_id                         0
# league_name                       0
# league_level                    450
# nationality_id                    0
# nationality_name                  0
# overall                           0
# attack                            0
# midfield                          0
# defence                           0
# coach_id                         37
# home_stadium                     12
# rival_team                        0
# international_prestige            0
# domestic_prestige               436
# transfer_budget_eur            1785
# club_worth_eur                 1618
# starting_xi_average_age           0
# whole_team_average_age            0
# captain                          38
# short_free_kick                  39
# ...

# %%
df_cleaned = df.dropna()

# %%
df = df.dropna(axis=1)

# %%
df.isnull().sum()
# Out:
# team_id                    0
# team_url                   0
# fifa_version               0
# fifa_update                0
# update_as_of               0
# team_name                  0
# league_id                  0
# league_name                0
# nationality_id             0
# nationality_name           0
# overall                    0
# attack                     0
# midfield                   0
# defence                    0
# rival_team                 0
# international_prestige     0
# starting_xi_average_age    0
# whole_team_average_age     0
# dtype: int64

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
df.head()
# Out:
#    team_id                           team_url  fifa_version  fifa_update  \
# 0       10    /team/10/manchester-city/240002            24            2
# 1      243       /team/243/real-madrid/240002            24            2
# 2     1318          /team/1318/england/240002            24            2
# 3       21  /team/21/fc-bayern-munchen/240002            24            2
# 4      241      /team/241/fc-barcelona/240002            24            2
#
#   update_as_of          team_name  league_id             league_name  \
# 0   2023-09-22    Manchester City         13          Premier League
# 1   2023-09-22        Real Madrid         53                 La Liga
# 2   2023-09-22            England         78  Friendly International
# 3   2023-09-22  FC Bayern München         19              Bundesliga
# 4   2023-09-22       FC Barcelona         53                 La Liga
#
#    nationality_id nationality_name  overall  attack  midfield  defence  \
# ...

# %%
print("Columns in df:")
print(df.columns.tolist())
# Out:
# Columns in df:
# ['team_id', 'team_url', 'fifa_version', 'fifa_update', 'update_as_of', 'team_name', 'league_id', 'league_name', 'nationality_id', 'nationality_name', 'overall', 'attack', 'midfield', 'defence', 'rival_team', 'international_prestige', 'starting_xi_average_age', 'whole_team_average_age']

# %%
columns_to_drop = ['team_url', 'fifa_update', 'fifa_version', 'update_as_of', 
                   'league_level', 'build_up_play_speed', 'build_up_play_dribbling', 
                   'build_up_play_passing', 'build_up_play_positioning', 
                   'chance_creation_passing', 'chance_creation_crossing', 
                   'chance_creation_shooting', 'chance_creation_positioning']

# %%
existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]

# %%
df = df.drop(existing_columns_to_drop, axis=1)

# %%
print("Cleaned DataFrame df:")
print(df.head())
# Out:
# Cleaned DataFrame df:
#    team_id          team_name  league_id             league_name  \
# 0       10    Manchester City         13          Premier League
# 1      243        Real Madrid         53                 La Liga
# 2     1318            England         78  Friendly International
# 3       21  FC Bayern München         19              Bundesliga
# 4      241       FC Barcelona         53                 La Liga
#
#    nationality_id nationality_name  overall  attack  midfield  defence  \
# 0              14          England       85      87        86       83
# 1              45            Spain       85      85        85       83
# 2              14          England       85      86        83       83
# 3              21          Germany       84      90        84       83
# 4              45            Spain       84      84        84       83
#
#    rival_team  international_prestige  starting_xi_average_age  \
# ...

# %%
df.head()
# Out:
#    team_id          team_name  league_id             league_name  \
# 0       10    Manchester City         13          Premier League
# 1      243        Real Madrid         53                 La Liga
# 2     1318            England         78  Friendly International
# 3       21  FC Bayern München         19              Bundesliga
# 4      241       FC Barcelona         53                 La Liga
#
#    nationality_id nationality_name  overall  attack  midfield  defence  \
# 0              14          England       85      87        86       83
# 1              45            Spain       85      85        85       83
# 2              14          England       85      86        83       83
# 3              21          Germany       84      90        84       83
# 4              45            Spain       84      84        84       83
#
#    rival_team  international_prestige  starting_xi_average_age  \
# 0          11                      10                    26.91
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Strip whitespace from column names
df.columns = df.columns.str.strip()

# %%
# Example: Histogram of the numerical variable in df_cleaned
plt.figure(figsize=(10, 6))
sns.histplot(df['overall'], bins=30, kde=True)  # Make sure to use the correct column name
plt.title('Distribution of overall')
plt.xlabel('overall')
plt.ylabel('Frequency')
plt.show()

# %%
# Example: Box plot to show the distribution of a numerical variable categorized by a categorical variable in df2_cleaned
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='attack', y='defence')  # Replace with your actual column names
plt.title('Box Plot of whole_team_average_age by starting_xi_average_age')
plt.xlabel('Team Attacks')
plt.ylabel('Team Defence')
plt.xticks(rotation=45)
plt.show()
