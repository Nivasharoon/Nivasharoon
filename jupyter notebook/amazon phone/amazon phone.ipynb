# %%
import pandas as pd

# %%
file_path = 'amazon phone.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#          asin                                      product_title  \
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1  B0CV2W1TKZ  Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...
# 2  B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 3  B0CHH1N9VY  TracFone | Motorola Moto g Pure | Locked | 32G...
# 4  B09T3MQSVP  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
#
#   product_price product_original_price currency  product_star_rating  \
# 0       $99.00                $169.99       USD                  4.0
# 1      $153.99                     NaN      USD                  4.2
# 2       $69.00                 $99.99       USD                  3.8
# 3       $49.99                     NaN      USD                  4.2
# 4       $88.09                 $98.27       USD                  3.8
#
#    product_num_ratings                           product_url  \
# 0                 1319  https://www.amazon.com/dp/B0BQ118F2T
# ...

# %%
df.tail()
# Out:
#            asin                                      product_title  \
# 335  B0CZ3YPSRX  Gimbal Stabilizer for Smartphone, 3-Axis Phone...
# 336  B0CHB24KQJ  [True Military-Grade] Car Phone Holder【2024 St...
# 337  B01LXOPZ4W  Wall Mount Cell Phone Charging Shelf | Multi-D...
# 338  B0CXPJK7F7  Sensyne 92&quot; Cell Phone Tripod, Selfie Sti...
# 339  B0CQ237PFS  Portable Charger 33800mAh USB C Power Bank wit...
#
#     product_price product_original_price currency  product_star_rating  \
# 335       $99.99                     NaN      USD                  4.7
# 336       $39.99                 $45.99       USD                  4.4
# 337      $273.00                     NaN      USD                  4.1
# 338       $29.99                     NaN      USD                  4.6
# 339       $45.95                 $69.95       USD                  4.4
#
#      product_num_ratings                           product_url  \
# 335                    8  https://www.amazon.com/dp/B0CZ3YPSRX
# ...

# %%
df.isnull().sum()
# Out:
# asin                             0
# product_title                    0
# product_price                    4
# product_original_price         192
# currency                         4
# product_star_rating              3
# product_num_ratings              0
# product_url                      0
# product_photo                    0
# product_num_offers               0
# product_minimum_offer_price      4
# is_best_seller                   0
# is_amazon_choice                 0
# is_prime                         0
# product_availability           265
# climate_pledge_friendly          0
# sales_volume                    20
# delivery                         3
# has_variations                   0
# unit_price                     336
# unit_count                     336
# coupon_text                    318
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [asin, product_title, product_price, product_original_price, currency, product_star_rating, product_num_ratings, product_url, product_photo, product_num_offers, product_minimum_offer_price, is_best_seller, is_amazon_choice, is_prime, product_availability, climate_pledge_friendly, sales_volume, delivery, has_variations, unit_price, unit_count, coupon_text]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# asin                             0
# product_title                    0
# product_price                    4
# product_original_price         192
# currency                         4
# product_star_rating              3
# product_num_ratings              0
# product_url                      0
# product_photo                    0
# product_num_offers               0
# product_minimum_offer_price      4
# is_best_seller                   0
# is_amazon_choice                 0
# is_prime                         0
# product_availability           265
# climate_pledge_friendly          0
# sales_volume                    20
# delivery                         3
# has_variations                   0
# unit_price                     336
# unit_count                     336
# coupon_text                    318
# dtype: int64

# %%
# Drop rows with any null values
df_cleaned = df.dropna()

# %%
# Drop columns with any null values
df_cleaned = df.dropna(axis=1)

# %%
df.isnull().sum()
# Out:
# asin                             0
# product_title                    0
# product_price                    4
# product_original_price         192
# currency                         4
# product_star_rating              3
# product_num_ratings              0
# product_url                      0
# product_photo                    0
# product_num_offers               0
# product_minimum_offer_price      4
# is_best_seller                   0
# is_amazon_choice                 0
# is_prime                         0
# product_availability           265
# climate_pledge_friendly          0
# sales_volume                    20
# delivery                         3
# has_variations                   0
# unit_price                     336
# unit_count                     336
# coupon_text                    318
# dtype: int64

# %%
df.shape
# Out:
# (340, 22)

# %%
df.head()
# Out:
#          asin                                      product_title  \
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1  B0CV2W1TKZ  Samsung Galaxy A15 (SM-155M/DSN), 128GB 6GB RA...
# 2  B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 3  B0CHH1N9VY  TracFone | Motorola Moto g Pure | Locked | 32G...
# 4  B09T3MQSVP  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
#
#   product_price product_original_price currency  product_star_rating  \
# 0       $99.00                $169.99       USD                  4.0
# 1      $153.99                     NaN      USD                  4.2
# 2       $69.00                 $99.99       USD                  3.8
# 3       $49.99                     NaN      USD                  4.2
# 4       $88.09                 $98.27       USD                  3.8
#
#    product_num_ratings                           product_url  \
# 0                 1319  https://www.amazon.com/dp/B0BQ118F2T
# ...

# %%
df = df.dropna(axis=1, how='all')

# %%
df.isnull().sum()
# Out:
# asin                             0
# product_title                    0
# product_price                    4
# product_original_price         192
# currency                         4
# product_star_rating              3
# product_num_ratings              0
# product_url                      0
# product_photo                    0
# product_num_offers               0
# product_minimum_offer_price      4
# is_best_seller                   0
# is_amazon_choice                 0
# is_prime                         0
# product_availability           265
# climate_pledge_friendly          0
# sales_volume                    20
# delivery                         3
# has_variations                   0
# unit_price                     336
# unit_count                     336
# coupon_text                    318
# dtype: int64

# %%
df = df.dropna(subset=['product_original_price'])

# %%
df.isnull().sum()
# Out:
# asin                             0
# product_title                    0
# product_price                    0
# product_original_price           0
# currency                         0
# product_star_rating              0
# product_num_ratings              0
# product_url                      0
# product_photo                    0
# product_num_offers               0
# product_minimum_offer_price      0
# is_best_seller                   0
# is_amazon_choice                 0
# is_prime                         0
# product_availability           113
# climate_pledge_friendly          0
# sales_volume                     0
# delivery                         0
# has_variations                   0
# unit_price                     146
# unit_count                     146
# coupon_text                    140
# dtype: int64

# %%
df = df.drop(['climate_pledge_friendly', 'product_url', 'product_photo', 'has_variations', 
               'is_best_seller', 'is_amazon_choice', 'is_prime', 
               'unit_price', 'unit_count', 'coupon_text', 
               'product_availability'], axis=1, errors='ignore')

# %%
df.isnull().sum()
# Out:
# asin                           0
# product_title                  0
# product_price                  0
# product_original_price         0
# currency                       0
# product_star_rating            0
# product_num_ratings            0
# product_num_offers             0
# product_minimum_offer_price    0
# sales_volume                   0
# delivery                       0
# dtype: int64

# %%
df.head()
# Out:
#          asin                                      product_title  \
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 2  B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 4  B09T3MQSVP  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
# 5  B0BZG14KFJ  Panasonic Cordless Phone with Answering Machin...
# 6  B0C2SWQBMB  Motorola Moto G 5G | 2023 | Unlocked | Made fo...
#
#   product_price product_original_price currency  product_star_rating  \
# 0       $99.00                $169.99       USD                  4.0
# 2       $69.00                 $99.99       USD                  3.8
# 4       $88.09                 $98.27       USD                  3.8
# 5       $49.99                 $59.99       USD                  4.4
# 6      $149.99                $249.99       USD                  4.2
#
#    product_num_ratings  product_num_offers product_minimum_offer_price  \
# 0                 1319                  16                     $69.88
# ...

# %%
df.to_csv('cleaned_amazon_phone.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df['product_star_rating'].describe())
# Out:
# count    148.000000
# mean       4.092568
# std        0.307080
# min        2.800000
# 25%        3.900000
# 50%        4.100000
# 75%        4.300000
# max        5.000000
# Name: product_star_rating, dtype: float64

# %%
# Check for missing values in the 'product_title' column
df['product_title'].isnull().sum()


# View the unique values in the column (to spot anomalies)
df['product_title'].unique()
# Out:
# array(['Moto G Play 2023 3-Day Battery Unlocked Made for US 3/32GB 16MP Camera Navy Blue',
#        'Samsung Galaxy A03s Cell Phone, AT&amp;T GSM Unlocked Android Smartphone, 32GB, Long Lasting Battery, Expandable Storage, 3 Camera Lenses, Infinite Display - Black (Renewed)',
#        'Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM Unlocked Android Smartphone, 64GB, Long Lasting Battery, Expandable Storage, Triple Lens Camera, Infinite Display, Black (Renewed)',
#        'Panasonic Cordless Phone with Answering Machine, Advanced Call Block, Bilingual Caller ID and Easy to Read High-Contrast Display, Expandable System with 2 Handsets - KX-TGD832M (Metallic Black)',
#        'Motorola Moto G 5G | 2023 | Unlocked | Made for US 4/128GB | 48 MPCamera | Ink Blue, 163.94x74.98x8.39',
#        'Samsung Galaxy A15 A155M 128GB Dual-SIM GSM Unlocked Android Smartphone (Latin America Version) - Light Blue',
# ...

# %%
# Shorten each product title to the first 30 characters
df['shortened_product_title'] = df['product_title'].str.slice(0, 30)

# View the updated DataFrame
df[['product_title', 'shortened_product_title']].head()
# Out:
#                                        product_title  \
# 0  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 2  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 4  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
# 5  Panasonic Cordless Phone with Answering Machin...
# 6  Motorola Moto G 5G | 2023 | Unlocked | Made fo...
#
#           shortened_product_title
# 0  Moto G Play 2023 3-Day Battery
# 2  Samsung Galaxy A03s Cell Phone
# 4  Samsung Galaxy A13 5G Cell Pho
# 5  Panasonic Cordless Phone with
# 6  Motorola Moto G 5G | 2023 | Un

# %%
# Example mapping for abbreviation
abbreviations = {
    'and': '&',
    'with': 'w/',
    'for': '4',
    'to': '2'
}

# Function to abbreviate titles
def abbreviate_title(title):
    for word, abbr in abbreviations.items():
        title = title.replace(f' {word} ', f' {abbr} ')
    return title

# Apply the abbreviation function
df['shortened_product_title'] = df['product_title'].apply(abbreviate_title)

# View the updated DataFrame
df[['product_title', 'shortened_product_title']].head()
# Out:
#                                        product_title  \
# 0  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 2  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 4  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
# 5  Panasonic Cordless Phone with Answering Machin...
# 6  Motorola Moto G 5G | 2023 | Unlocked | Made fo...
#
#                              shortened_product_title
# 0  Moto G Play 2023 3-Day Battery Unlocked Made 4...
# 2  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 4  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
# 5  Panasonic Cordless Phone w/ Answering Machine,...
# 6  Motorola Moto G 5G | 2023 | Unlocked | Made 4 ...

# %%
# Extract the first 3 words from each title
df['shortened_product_title'] = df['product_title'].apply(lambda x: ' '.join(x.split()[:3]))

# View the updated DataFrame
df[['product_title', 'shortened_product_title']].head()
# Out:
#                                        product_title   shortened_product_title
# 0  Moto G Play 2023 3-Day Battery Unlocked Made f...               Moto G Play
# 2  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...       Samsung Galaxy A03s
# 4  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...        Samsung Galaxy A13
# 5  Panasonic Cordless Phone with Answering Machin...  Panasonic Cordless Phone
# 6  Motorola Moto G 5G | 2023 | Unlocked | Made fo...           Motorola Moto G

# %%
import pandas as pd

# Load your dataset (replace 'your_dataset.csv' with the actual file name)
df = pd.read_csv('cleaned_amazon_phone.csv')

# Shorten each title to the first 30 characters
df['shortened_product_title'] = df['product_title'].str.slice(0, 30)

# Extract the first 3 words
df['first_three_words'] = df['product_title'].apply(lambda x: ' '.join(x.split()[:3]))

# View the updated DataFrame
df[['product_title', 'shortened_product_title', 'first_three_words']].head()

# Save the updated DataFrame if needed
df.to_csv('updated_dataset.csv', index=False)

# %%
print("Original Product Titles:")
df['product_title'].head()  # Show the first 5 original titles

# Shorten each title to the first 30 characters
df['shortened_product_title'] = df['product_title'].str.slice(0, 30)

# Extract the first 3 words
df['first_three_words'] = df['product_title'].apply(lambda x: ' '.join(x.split()[:3]))

# Display the updates
print("\nUpdated Product Titles:")
df[['product_title', 'shortened_product_title', 'first_three_words']].head()
# Out:
# Original Product Titles:
#
# Updated Product Titles:
#                                        product_title  \
# 0  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 2  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
# 3  Panasonic Cordless Phone with Answering Machin...
# 4  Motorola Moto G 5G | 2023 | Unlocked | Made fo...
#
#           shortened_product_title         first_three_words
# 0  Moto G Play 2023 3-Day Battery               Moto G Play
# 1  Samsung Galaxy A03s Cell Phone       Samsung Galaxy A03s
# 2  Samsung Galaxy A13 5G Cell Pho        Samsung Galaxy A13
# 3  Panasonic Cordless Phone with   Panasonic Cordless Phone
# 4  Motorola Moto G 5G | 2023 | Un           Motorola Moto G

# %%
df['shortened_product_title'] = df['product_title'].str.slice(0, 30)

# Extract the first 3 words
df['first_three_words'] = df['product_title'].apply(lambda x: ' '.join(x.split()[:3]))

# Save the updated DataFrame to a new CSV file
df.to_csv('updated_dataset.csv', index=False)

print("Updated dataset has been saved as 'updated_dataset.csv'.")
# Out:
# Updated dataset has been saved as 'updated_dataset.csv'.

# %%
df.head()
# Out:
#          asin                                      product_title  \
# 0  B0BQ118F2T  Moto G Play 2023 3-Day Battery Unlocked Made f...
# 1  B09SM24S8C  Samsung Galaxy A03s Cell Phone, AT&amp;T GSM U...
# 2  B09T3MQSVP  Samsung Galaxy A13 5G Cell Phone, AT&amp;T GSM...
# 3  B0BZG14KFJ  Panasonic Cordless Phone with Answering Machin...
# 4  B0C2SWQBMB  Motorola Moto G 5G | 2023 | Unlocked | Made fo...
#
#   product_price product_original_price currency  product_star_rating  \
# 0       $99.00                $169.99       USD                  4.0
# 1       $69.00                 $99.99       USD                  3.8
# 2       $88.09                 $98.27       USD                  3.8
# 3       $49.99                 $59.99       USD                  4.4
# 4      $149.99                $249.99       USD                  4.2
#
#    product_num_ratings  product_num_offers product_minimum_offer_price  \
# 0                 1319                  16                     $69.88
# ...

# %%
df.columns
# Out:
# Index(['asin', 'product_title', 'product_price', 'product_original_price',
#        'currency', 'product_star_rating', 'product_num_ratings',
#        'product_num_offers', 'product_minimum_offer_price', 'sales_volume',
#        'delivery', 'shortened_product_title', 'first_three_words'],
#       dtype='object')

# %%
df = df[['asin','first_three_words','shortened_product_title','product_title', 'product_price', 'product_original_price',
       'currency', 'product_star_rating', 'product_num_ratings',
       'product_num_offers', 'product_minimum_offer_price', 'sales_volume',
       'delivery']]

# %%
df.drop(columns=['product_title'], inplace=True)

# %%
df.to_csv('updated_dataset.csv', index=False)

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['product_star_rating'], bins=5, kde=True)
plt.title('Distribution of Product Star Ratings')
plt.xlabel('Star Rating')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset (make sure the file path is correct)
df = pd.read_csv('cleaned_amazon_phone.csv')

# Select only the relevant columns and drop rows with missing values
df_cleaned = df[['product_price', 'product_original_price']].dropna()

# Create a pair plot for the two columns
sns.pairplot(df)

# Add a title
plt.suptitle('Pair Plot: Product Price vs Original Price', y=1.02, fontsize=16)

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('cleaned_amazon_phone.csv')

# Set the size of the figure
plt.figure(figsize=(10, 6))

# Create a histogram of a specific column (e.g., 'column_name')
sns.histplot(df['product_num_offers'].dropna(), bins=30, kde=True)


# Add a title and labels
plt.title('Histogram of sales_volume ', fontsize=16)
plt.xlabel('sales_volume')
plt.ylabel('asin')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('cleaned_amazon_phone.csv')

# Drop rows with missing values in the specified column
df_cleaned = df['product_price'].dropna()

# Calculate the value counts for each category
category_counts = df_cleaned.value_counts()

# Set the figure size
plt.figure(figsize=(4, 4))

# Create a pie chart
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Add a title
plt.title('Pie Chart of product_minimum_offer_price', fontsize=16)

# Show the plot
plt.show()
